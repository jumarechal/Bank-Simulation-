# %%
import tkinter as tk
import time 
import threading 
import simpy
import random
import sys
import numpy as np
sys.setrecursionlimit(10000000)

# %%
fenetre = tk.Tk()

canvas = tk.Canvas(fenetre, width=800, height=600, background='green')
rect = canvas.create_rectangle(300, 0, 400, 600,fill='blue')
base = canvas.create_rectangle(380,280,420,320, fill='red')
coords = []
c = []
t = []
beta = 15
nb_call = 5
nb_counter = 5
nb_boat = 2
counter = [True]*nb_counter
dispo = []
call_list = []
for k in range(nb_counter): 
    dispo.append(canvas.create_rectangle(290,100*(k+1)-10,310,100*(k+1)+10,fill='yellow'))


class Call: 
    def __init__(self, location, position): 
        self.location = location
        self.position = position 
    
def generate_call(): 
    print("generation de call")
    time.sleep(2.0)
    for i in range (nb_call): 
        pb = random.randint(1, nb_counter)
        call_list.append(Call((100*(pb)-10, 100*pb+10), pb-1))
        canvas.itemconfigure(dispo[pb-1], fill='red')
        print(pb - 1)
        TBC = np.random.exponential(scale=beta, size=1)
        time.sleep(2.0) 
        
        
class myThread(threading.Thread):
    def __init__(self, i):
        threading.Thread.__init__(self)
        self.i = i
        self.dispo = True 
        self.going = False
        self.arrival = False
        self.retour = False 
        self.arriver_base = False 
        self.community = -1
        self.deplacement = 0
        
    def run(self):
        self.running = True
        while(self.running): 
            if(self.dispo): 
                if(not (not call_list)): 
                    self.location = call_list[0].location 
                    self.community = call_list[0].position
                    del call_list[0]
                    self.going = True 
                    self.dispo = False 
                    #self.compteur = self.compteur + 1 
                    if (coords[self.i][1] > self.location[0]): 
                        self.deplacement = -10
                    elif (coords[self.i][1] < self.location[0]): 
                        self.deplacement = +10 
                    else: 
                        self.deplacement = 0 
            while(self.going):
                time.sleep(0.05)
                self.bouger()
                if(coords[self.i][1] == self.location[0]): 
                    self.arrival = True
                    self.going = False 
            while(self.arrival):
                time.sleep(0.01)
                self.arriver()
                if (coords[self.i][0] == 310 ): 
                    self.arrival = False
                    self.retour = True 
            self.traitement()
            while(self.retour):
                time.sleep(0.05)
                self.revenir()
                if (coords[self.i][1] == 290): 
                    self.retour = False 
                    self.arriver_base = True 
            while(self.arriver_base): 
                time.sleep(0.01)
                self.come_back()
                if(coords[self.i][0] == 385): 
                    self.arriver_base = False 
                    self.dispo = True 
                
            #time.sleep(0.1)
            fenetre.after(1, self.run())
            
#             if(self.compteur == nb_call - 1): 
#                 print("j'arrete le thread")
#                 t[i].arret()
                
                
    def bouger(self):       
        coords[self.i] = (coords[self.i][0] - 1, coords[self.i][1] + self.deplacement)
        canvas.coords(c[self.i], coords[self.i][0], coords[self.i][1], coords[self.i][0]+20, coords[self.i][1]+20) 
        
    def arriver(self):       
        coords[self.i] = (coords[self.i][0] - 1, coords[self.i][1])
        canvas.coords(c[self.i], coords[self.i][0], coords[self.i][1], coords[self.i][0]+20, coords[self.i][1]+20) 
        
    def revenir(self):       
        coords[self.i] = (coords[self.i][0] + 1, coords[self.i][1] - self.deplacement)
        canvas.coords(c[self.i], coords[self.i][0], coords[self.i][1], coords[self.i][0]+20, coords[self.i][1]+20)
        
    def come_back(self):       
        coords[self.i] = (coords[self.i][0] + 1, coords[self.i][1])
        canvas.coords(c[self.i], coords[self.i][0], coords[self.i][1], coords[self.i][0]+20, coords[self.i][1]+20)
        
    def arret(self): 
        self.running = False 
                
    def traitement(self): 
        time.sleep(2.0)
        canvas.itemconfigure(dispo[self.community], fill='yellow')

        
def apparition(i):
    c.append(canvas.create_rectangle(385+10*i,290,405+10*i,310,fill='#00FFFF'))
    coords.append((385+10*i, 290))
        
        
        
def source():
    for i in range(0,nb_boat):  
        apparition(i)
        fenetre.update()
        t.append(myThread(i))
        t[i].start()
        
        
        
random.seed()  

canvas.pack()
draw = threading.Thread(target=source)
draw.start()
appel = threading.Thread(target=generate_call)
appel.start()



fenetre.mainloop()
# Out:
# generation de call
# 0
# 1
# 4
# 4
# 1
# Exception in thread Thread-74:
# Traceback (most recent call last):
#   File "C:\Users\A15-03\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   [Previous line repeated 3 more times]
#   File "<ipython-input-22-64c99b50630e>", line 78, in run
#     self.traitement()
#   File "<ipython-input-22-64c99b50630e>", line 121, in traitement
#     canvas.itemconfigure(dispo[self.community], fill='yellow')
#   File "C:\Users\A15-03\Anaconda3\lib\tkinter\__init__.py", line 2572, in itemconfigure
#     return self._configure(('itemconfigure', tagOrId), cnf, kw)
#   File "C:\Users\A15-03\Anaconda3\lib\tkinter\__init__.py", line 1470, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# RuntimeError: main thread is not in main loop
#
# Exception in thread Thread-75:
# Traceback (most recent call last):
#   File "C:\Users\A15-03\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   File "<ipython-input-22-64c99b50630e>", line 93, in run
#     fenetre.after(1, self.run())
#   [Previous line repeated 5 more times]
#   File "<ipython-input-22-64c99b50630e>", line 78, in run
#     self.traitement()
#   File "<ipython-input-22-64c99b50630e>", line 121, in traitement
#     canvas.itemconfigure(dispo[self.community], fill='yellow')
#   File "C:\Users\A15-03\Anaconda3\lib\tkinter\__init__.py", line 2572, in itemconfigure
#     return self._configure(('itemconfigure', tagOrId), cnf, kw)
#   File "C:\Users\A15-03\Anaconda3\lib\tkinter\__init__.py", line 1470, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# RuntimeError: main thread is not in main loop

# %%
tab = [1,2,3,4,5]
for i in range (3): 
    del tab[0]
tab
# Out:
# [4, 5]
