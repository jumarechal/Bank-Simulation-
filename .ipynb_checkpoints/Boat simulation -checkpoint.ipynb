# %%
import numpy as np
import matplotlib.pyplot as plt
import tkinter
import simpy
import random
import time 
import pandas 
import csv

# %%
class Location:
    def __init__(self, name=None, distance=None):
        self.name = name
        self.distance = distance

# %%
class Call:
    id_call = 0 
    def __init__(self, ID=None, initial_time=None, final_time=None, status=None, location=None):
        Call.id_call = Call.id_call + 1
        self.ID = Call.id_call
        self.initial_time = initial_time
        self.final_time = final_time
        self.status = status 
        self.location = location
         
        
    def detail(self):
        print('Call from {} received at {}'.format(self.location.name, self.initial_time))
        
    def generate_Call(self, env, beta, locations, distance, p, counter, boat_list, lastCall=None):
        self.location = Location()
        self.location.name = np.random.choice(locations, 1, p)
        self.location.distance = distance[' '.join(self.location.name)]

        if (lastCall==None):
            self.initial_time = float (np.random.exponential(scale=beta, size=1))
            yield env.timeout(self.initial_time)
        else:    
            self.initial_time = float (lastCall.initial_time + np.random.exponential(scale=beta, size=1))
            yield env.timeout(self.initial_time)

        print('%7.4f Call %d received from %s at a distance of %d' % (env.now, self.ID, self.location.name, self.location.distance))
        
        with counter.request() as req:
            yield req
            wait = env.now - self.initial_time #waiting time 
            print('%7.4f Call %d: Waited %6.3f' % (env.now, self.ID, wait))
            yield env.process(trajet(env, boat_list, self, wait))
            print('%7.4f Call %d: Finished' % (env.now, self.ID))

        self.status = 1

# %%
def trajet(env, boat_list, call, wait): 
    i = 0 
    while(i != len(boat_list) and boat_list[i].status != 0): #while you don't have a boat available 
        i = i + 1
    if(i != len(boat_list) and boat_list[i].status == 0): #if you have a boat available
        boat_list[i].status = 1 
        intervention = Intervention()
        print('Boat {} with a speed of {} respond to the call {} '.format(boat_list[i].ID, boat_list[i].speed, call.ID))
        intervention.boat = boat_list[i]
        intervention.call = call
        intervention.travel_time = call.location.distance/boat_list[i].speed
        intervention.TOS = 0.25
        intervention.waited_time = wait 
        intervention.response_time = intervention.travel_time + wait 
        intervention.road_time = 2*intervention.travel_time + intervention.TOS 
        inter_list.append(intervention)
        yield env.timeout(intervention.road_time)
        call.final_time = call.initial_time + intervention.road_time 
        print('Duration of the intervention {} : {} '.format(intervention.ID, intervention.road_time))
        boat_list[i].status = 0

# %%
class Intervention: 
    nb_inter = 0 
    def __init__(self, travel_time=None, TOS=None, response_time=None, road_time = None, waited_time=None, boat=None, call=None):
        Intervention.nb_inter = Intervention.nb_inter + 1 
        self.ID = Intervention.nb_inter
        self.travel_time = travel_time
        self.TOS = TOS
        self.response_time = response_time 
        self.road_time = road_time 
        self.waited_time = waited_time 
        self.boat = boat
        self.call = call
        
    def to_dict(self): 
        return {
            'ID intervention': self.ID,
            'Boat associated': self.boat.ID,
            'Call traited': self.call.ID,
            'travel time': self.travel_time,
            'Time On Scene': self.TOS,
            'response time': self.response_time,
            'waited time': self.waited_time,
            'total time': self.road_time, 
        }

# %%
class Boat: 
    nb_boat = 0 
    def __init__(self, env, speed=None, status=None): 
        Boat.nb_boat = Boat.nb_boat + 1 
        self.ID = Boat.nb_boat 
        self.speed = speed 
        self.status = status

# %%
def source(env, counter): 
    yield env.timeout(0)
    print('%7.4f Start' % (env.now))
    for i in range(nb_call):
        call_list.append(Call())
        if i == 0: 
            env.process(call_list[i].generate_Call(env, 15,locations, distance, p, counter, boat_list))
        else: 
            env.process(call_list[i].generate_Call(env, 15, locations, distance, p, counter, boat_list, call_list[i-1]))

# %%
#Define the variables
locations = ['N SRA CARMO', 'N SRA P. SOCORRO', 'BONSUCESSO', 'ASS. NAZARE', 'GUAJARA', 
            'ARUAU', 'MIPINDIAU', 'CUIEIRAS', 'SANTA MARIA', 'JARAQUI', 'COSTA DOS ARARAS', 
            'COSTA DO TATU', 'AGROVILA', 'N. SRA. FATIMA', 'LIVRAMENTO']

p=[0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06]

distance = {'N SRA CARMO':100, 'N SRA P. SOCORRO':90, 'BONSUCESSO':80, 'ASS. NAZARE':70, 'GUAJARA':60, 
            'ARUAU':100, 'MIPINDIAU':90, 'CUIEIRAS':75, 'SANTA MARIA':60, 'JARAQUI':52, 'COSTA DOS ARARAS':50, 
            'COSTA DO TATU':30, 'AGROVILA':20, 'N. SRA. FATIMA':15, 'LIVRAMENTO':15}
nb_boat = 1
nb_call = 100
call_list = []
boat_list = []
inter_list = []

# %%
#Setup and lauch of the simulation 
env = simpy.Environment()
for i in range(nb_boat): 
    boat_list.append(Boat(env,45,0))
    #boat_list.append(Boat(env,30,0))
counter = simpy.Resource(env, capacity=nb_boat)
env.process(source(env, counter))
env.run()

print ("list of intervention")
for inter in inter_list: 
    print("Intervention {} : for call {} with boat {} take {} ".format(inter.ID, inter.call.ID, inter.boat.ID, inter.road_time))
# Out:
#  0.0000 Start
#  4.6355 Call 1 received from ['COSTA DO TATU'] at a distance of 30
#  4.6355 Call 1: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 1
# Duration of the intervention 1 : 1.5833333333333333
#  6.2188 Call 1: Finished
# 19.1335 Call 2 received from ['N. SRA. FATIMA'] at a distance of 15
# 19.1335 Call 2: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 2
# Duration of the intervention 2 : 0.9166666666666666
# 20.0501 Call 2: Finished
# 20.7323 Call 3 received from ['GUAJARA'] at a distance of 60
# 20.7323 Call 3: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 3
# Duration of the intervention 3 : 2.9166666666666665
# 23.6490 Call 3: Finished
# 25.6547 Call 4 received from ['SANTA MARIA'] at a distance of 60
# 25.6547 Call 4: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 4
# Duration of the intervention 4 : 2.9166666666666665
# 28.5714 Call 4: Finished
# 34.1153 Call 5 received from ['JARAQUI'] at a distance of 52
# 34.1153 Call 5: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 5
# Duration of the intervention 5 : 2.561111111111111
# 36.6765 Call 5: Finished
# 59.0602 Call 6 received from ['N SRA CARMO'] at a distance of 100
# 59.0602 Call 6: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 6
# 60.3786 Call 7 received from ['CUIEIRAS'] at a distance of 75
# Duration of the intervention 6 : 4.694444444444445
# 63.7546 Call 6: Finished
# 63.7546 Call 7: Waited  3.376
# Boat 1 with a speed of 45 respond to the call 7
# 64.9482 Call 8 received from ['COSTA DO TATU'] at a distance of 30
# Duration of the intervention 7 : 3.5833333333333335
# 67.3379 Call 7: Finished
# 67.3379 Call 8: Waited  2.390
# Boat 1 with a speed of 45 respond to the call 8
# Duration of the intervention 8 : 1.5833333333333333
# 68.9213 Call 8: Finished
# 81.9174 Call 9 received from ['MIPINDIAU'] at a distance of 90
# 81.9174 Call 9: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 9
# 85.4511 Call 10 received from ['ARUAU'] at a distance of 100
# Duration of the intervention 9 : 4.25
# 86.1674 Call 9: Finished
# 86.1674 Call 10: Waited  0.716
# Boat 1 with a speed of 45 respond to the call 10
# Duration of the intervention 10 : 4.694444444444445
# 90.8618 Call 10: Finished
# 95.7690 Call 11 received from ['BONSUCESSO'] at a distance of 80
# 95.7690 Call 11: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 11
# 98.1101 Call 12 received from ['N. SRA. FATIMA'] at a distance of 15
# Duration of the intervention 11 : 3.8055555555555554
# 99.5746 Call 11: Finished
# 99.5746 Call 12: Waited  1.464
# Boat 1 with a speed of 45 respond to the call 12
# Duration of the intervention 12 : 0.9166666666666666
# 100.4913 Call 12: Finished
# 128.3094 Call 13 received from ['JARAQUI'] at a distance of 52
# 128.3094 Call 13: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 13
# Duration of the intervention 13 : 2.561111111111111
# 130.8706 Call 13: Finished
# 131.9726 Call 14 received from ['COSTA DO TATU'] at a distance of 30
# 131.9726 Call 14: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 14
# Duration of the intervention 14 : 1.5833333333333333
# 133.5559 Call 14: Finished
# 136.9922 Call 15 received from ['GUAJARA'] at a distance of 60
# 136.9922 Call 15: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 15
# Duration of the intervention 15 : 2.9166666666666665
# 139.9089 Call 15: Finished
# 151.7638 Call 16 received from ['N SRA P. SOCORRO'] at a distance of 90
# 151.7638 Call 16: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 16
# Duration of the intervention 16 : 4.25
# 156.0138 Call 16: Finished
# 188.9621 Call 17 received from ['ARUAU'] at a distance of 100
# 188.9621 Call 17: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 17
# Duration of the intervention 17 : 4.694444444444445
# 193.6565 Call 17: Finished
# 203.3993 Call 18 received from ['COSTA DOS ARARAS'] at a distance of 50
# 203.3993 Call 18: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 18
# Duration of the intervention 18 : 2.4722222222222223
# 205.8715 Call 18: Finished
# 214.3420 Call 19 received from ['LIVRAMENTO'] at a distance of 15
# 214.3420 Call 19: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 19
# Duration of the intervention 19 : 0.9166666666666666
# 215.2587 Call 19: Finished
# 226.1642 Call 20 received from ['AGROVILA'] at a distance of 20
# 226.1642 Call 20: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 20
# Duration of the intervention 20 : 1.1388888888888888
# 227.3031 Call 20: Finished
# 236.6576 Call 21 received from ['MIPINDIAU'] at a distance of 90
# 236.6576 Call 21: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 21
# Duration of the intervention 21 : 4.25
# 240.9076 Call 21: Finished
# 242.6173 Call 22 received from ['N. SRA. FATIMA'] at a distance of 15
# 242.6173 Call 22: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 22
# Duration of the intervention 22 : 0.9166666666666666
# 243.5340 Call 22: Finished
# 255.7232 Call 23 received from ['ARUAU'] at a distance of 100
# 255.7232 Call 23: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 23
# Duration of the intervention 23 : 4.694444444444445
# 260.4176 Call 23: Finished
# 307.3939 Call 24 received from ['CUIEIRAS'] at a distance of 75
# 307.3939 Call 24: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 24
# 309.3466 Call 25 received from ['N SRA CARMO'] at a distance of 100
# Duration of the intervention 24 : 3.5833333333333335
# 310.9773 Call 24: Finished
# 310.9773 Call 25: Waited  1.631
# Boat 1 with a speed of 45 respond to the call 25
# 313.3684 Call 26 received from ['N SRA P. SOCORRO'] at a distance of 90
# Duration of the intervention 25 : 4.694444444444445
# 315.6717 Call 25: Finished
# 315.6717 Call 26: Waited  2.303
# Boat 1 with a speed of 45 respond to the call 26
# 318.5608 Call 27 received from ['CUIEIRAS'] at a distance of 75
# Duration of the intervention 26 : 4.25
# 319.9217 Call 26: Finished
# 319.9217 Call 27: Waited  1.361
# Boat 1 with a speed of 45 respond to the call 27
# Duration of the intervention 27 : 3.5833333333333335
# 323.5051 Call 27: Finished
# 329.9106 Call 28 received from ['JARAQUI'] at a distance of 52
# 329.9106 Call 28: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 28
# 330.7773 Call 29 received from ['ASS. NAZARE'] at a distance of 70
# Duration of the intervention 28 : 2.561111111111111
# 332.4717 Call 28: Finished
# 332.4717 Call 29: Waited  1.694
# Boat 1 with a speed of 45 respond to the call 29
# Duration of the intervention 29 : 3.361111111111111
# 335.8329 Call 29: Finished
# 373.6742 Call 30 received from ['N SRA P. SOCORRO'] at a distance of 90
# 373.6742 Call 30: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 30
# 375.1718 Call 31 received from ['N SRA CARMO'] at a distance of 100
# Duration of the intervention 30 : 4.25
# 377.9242 Call 30: Finished
# 377.9242 Call 31: Waited  2.752
# Boat 1 with a speed of 45 respond to the call 31
# Duration of the intervention 31 : 4.694444444444445
# 382.6186 Call 31: Finished
# 408.8868 Call 32 received from ['SANTA MARIA'] at a distance of 60
# 408.8868 Call 32: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 32
# Duration of the intervention 32 : 2.9166666666666665
# 411.8035 Call 32: Finished
# 415.9280 Call 33 received from ['CUIEIRAS'] at a distance of 75
# 415.9280 Call 33: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 33
# Duration of the intervention 33 : 3.5833333333333335
# 419.5114 Call 33: Finished
# 421.3002 Call 34 received from ['CUIEIRAS'] at a distance of 75
# 421.3002 Call 34: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 34
# Duration of the intervention 34 : 3.5833333333333335
# 424.8836 Call 34: Finished
# 429.2737 Call 35 received from ['GUAJARA'] at a distance of 60
# 429.2737 Call 35: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 35
# Duration of the intervention 35 : 2.9166666666666665
# 432.1904 Call 35: Finished
# 458.5560 Call 36 received from ['COSTA DOS ARARAS'] at a distance of 50
# 458.5560 Call 36: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 36
# Duration of the intervention 36 : 2.4722222222222223
# 461.0282 Call 36: Finished
# 465.1896 Call 37 received from ['ARUAU'] at a distance of 100
# 465.1896 Call 37: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 37
# Duration of the intervention 37 : 4.694444444444445
# 469.8841 Call 37: Finished
# 484.8497 Call 38 received from ['CUIEIRAS'] at a distance of 75
# 484.8497 Call 38: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 38
# Duration of the intervention 38 : 3.5833333333333335
# 488.4330 Call 38: Finished
# 501.8129 Call 39 received from ['COSTA DOS ARARAS'] at a distance of 50
# 501.8129 Call 39: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 39
# Duration of the intervention 39 : 2.4722222222222223
# 504.2851 Call 39: Finished
# 509.2975 Call 40 received from ['LIVRAMENTO'] at a distance of 15
# 509.2975 Call 40: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 40
# Duration of the intervention 40 : 0.9166666666666666
# 510.2142 Call 40: Finished
# 526.7546 Call 41 received from ['COSTA DO TATU'] at a distance of 30
# 526.7546 Call 41: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 41
# Duration of the intervention 41 : 1.5833333333333333
# 528.3379 Call 41: Finished
# 541.9124 Call 42 received from ['N SRA P. SOCORRO'] at a distance of 90
# 541.9124 Call 42: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 42
# 542.6421 Call 43 received from ['COSTA DOS ARARAS'] at a distance of 50
# Duration of the intervention 42 : 4.25
# 546.1624 Call 42: Finished
# 546.1624 Call 43: Waited  3.520
# Boat 1 with a speed of 45 respond to the call 43
# 547.2054 Call 44 received from ['SANTA MARIA'] at a distance of 60
# Duration of the intervention 43 : 2.4722222222222223
# 548.6346 Call 43: Finished
# 548.6346 Call 44: Waited  1.429
# Boat 1 with a speed of 45 respond to the call 44
# Duration of the intervention 44 : 2.9166666666666665
# 551.5513 Call 44: Finished
# 573.6843 Call 45 received from ['N. SRA. FATIMA'] at a distance of 15
# 573.6843 Call 45: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 45
# Duration of the intervention 45 : 0.9166666666666666
# 574.6010 Call 45: Finished
# 599.3868 Call 46 received from ['COSTA DOS ARARAS'] at a distance of 50
# 599.3868 Call 46: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 46
# Duration of the intervention 46 : 2.4722222222222223
# 601.8590 Call 46: Finished
# 626.5700 Call 47 received from ['ASS. NAZARE'] at a distance of 70
# 626.5700 Call 47: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 47
# 628.9111 Call 48 received from ['LIVRAMENTO'] at a distance of 15
# Duration of the intervention 47 : 3.361111111111111
# 629.9311 Call 47: Finished
# 629.9311 Call 48: Waited  1.020
# Boat 1 with a speed of 45 respond to the call 48
# Duration of the intervention 48 : 0.9166666666666666
# 630.8478 Call 48: Finished
# 645.6023 Call 49 received from ['COSTA DOS ARARAS'] at a distance of 50
# 645.6023 Call 49: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 49
# Duration of the intervention 49 : 2.4722222222222223
# 648.0745 Call 49: Finished
# 654.0143 Call 50 received from ['N SRA CARMO'] at a distance of 100
# 654.0143 Call 50: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 50
# Duration of the intervention 50 : 4.694444444444445
# 658.7088 Call 50: Finished
# 666.4491 Call 51 received from ['N SRA P. SOCORRO'] at a distance of 90
# 666.4491 Call 51: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 51
# Duration of the intervention 51 : 4.25
# 670.6991 Call 51: Finished
# 679.7124 Call 52 received from ['ARUAU'] at a distance of 100
# 679.7124 Call 52: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 52
# Duration of the intervention 52 : 4.694444444444445
# 684.4069 Call 52: Finished
# 688.3807 Call 53 received from ['BONSUCESSO'] at a distance of 80
# 688.3807 Call 53: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 53
# 688.9721 Call 54 received from ['ARUAU'] at a distance of 100
# Duration of the intervention 53 : 3.8055555555555554
# 692.1863 Call 53: Finished
# 692.1863 Call 54: Waited  3.214
# Boat 1 with a speed of 45 respond to the call 54
# Duration of the intervention 54 : 4.694444444444445
# 696.8807 Call 54: Finished
# 708.1891 Call 55 received from ['LIVRAMENTO'] at a distance of 15
# 708.1891 Call 55: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 55
# Duration of the intervention 55 : 0.9166666666666666
# 709.1057 Call 55: Finished
# 719.5020 Call 56 received from ['N. SRA. FATIMA'] at a distance of 15
# 719.5020 Call 56: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 56
# Duration of the intervention 56 : 0.9166666666666666
# 720.4187 Call 56: Finished
# 726.9351 Call 57 received from ['N. SRA. FATIMA'] at a distance of 15
# 726.9351 Call 57: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 57
# Duration of the intervention 57 : 0.9166666666666666
# 727.8517 Call 57: Finished
# 742.1813 Call 58 received from ['COSTA DO TATU'] at a distance of 30
# 742.1813 Call 58: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 58
# Duration of the intervention 58 : 1.5833333333333333
# 743.7646 Call 58: Finished
# 757.2828 Call 59 received from ['CUIEIRAS'] at a distance of 75
# 757.2828 Call 59: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 59
# Duration of the intervention 59 : 3.5833333333333335
# 760.8661 Call 59: Finished
# 764.8471 Call 60 received from ['COSTA DOS ARARAS'] at a distance of 50
# 764.8471 Call 60: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 60
# Duration of the intervention 60 : 2.4722222222222223
# 767.3193 Call 60: Finished
# 770.2515 Call 61 received from ['COSTA DO TATU'] at a distance of 30
# 770.2515 Call 61: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 61
# Duration of the intervention 61 : 1.5833333333333333
# 771.8348 Call 61: Finished
# 780.4553 Call 62 received from ['GUAJARA'] at a distance of 60
# 780.4553 Call 62: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 62
# Duration of the intervention 62 : 2.9166666666666665
# 783.3720 Call 62: Finished
# 785.7730 Call 63 received from ['LIVRAMENTO'] at a distance of 15
# 785.7730 Call 63: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 63
# Duration of the intervention 63 : 0.9166666666666666
# 786.6896 Call 63: Finished
# 811.3868 Call 64 received from ['COSTA DO TATU'] at a distance of 30
# 811.3868 Call 64: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 64
# Duration of the intervention 64 : 1.5833333333333333
# 812.9701 Call 64: Finished
# 828.3463 Call 65 received from ['N SRA P. SOCORRO'] at a distance of 90
# 828.3463 Call 65: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 65
# Duration of the intervention 65 : 4.25
# 832.5963 Call 65: Finished
# 839.8998 Call 66 received from ['COSTA DO TATU'] at a distance of 30
# 839.8998 Call 66: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 66
# Duration of the intervention 66 : 1.5833333333333333
# 841.4831 Call 66: Finished
# 848.1546 Call 67 received from ['N. SRA. FATIMA'] at a distance of 15
# 848.1546 Call 67: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 67
# Duration of the intervention 67 : 0.9166666666666666
# 849.0713 Call 67: Finished
# 900.5795 Call 68 received from ['SANTA MARIA'] at a distance of 60
# 900.5795 Call 68: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 68
# Duration of the intervention 68 : 2.9166666666666665
# 903.4961 Call 68: Finished
# 949.2588 Call 69 received from ['COSTA DO TATU'] at a distance of 30
# 949.2588 Call 69: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 69
# Duration of the intervention 69 : 1.5833333333333333
# 950.8422 Call 69: Finished
# 964.7750 Call 70 received from ['AGROVILA'] at a distance of 20
# 964.7750 Call 70: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 70
# Duration of the intervention 70 : 1.1388888888888888
# 965.9139 Call 70: Finished
# 983.6778 Call 71 received from ['MIPINDIAU'] at a distance of 90
# 983.6778 Call 71: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 71
# Duration of the intervention 71 : 4.25
# 987.9278 Call 71: Finished
# 992.9064 Call 72 received from ['CUIEIRAS'] at a distance of 75
# 992.9064 Call 72: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 72
# 995.1121 Call 73 received from ['N. SRA. FATIMA'] at a distance of 15
# Duration of the intervention 72 : 3.5833333333333335
# 996.4898 Call 72: Finished
# 996.4898 Call 73: Waited  1.378
# Boat 1 with a speed of 45 respond to the call 73
# Duration of the intervention 73 : 0.9166666666666666
# 997.4064 Call 73: Finished
# 1023.8423 Call 74 received from ['LIVRAMENTO'] at a distance of 15
# 1023.8423 Call 74: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 74
# Duration of the intervention 74 : 0.9166666666666666
# 1024.7589 Call 74: Finished
# 1027.5309 Call 75 received from ['LIVRAMENTO'] at a distance of 15
# 1027.5309 Call 75: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 75
# Duration of the intervention 75 : 0.9166666666666666
# 1028.4476 Call 75: Finished
# 1031.6903 Call 76 received from ['COSTA DO TATU'] at a distance of 30
# 1031.6903 Call 76: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 76
# Duration of the intervention 76 : 1.5833333333333333
# 1033.2737 Call 76: Finished
# 1058.1747 Call 77 received from ['ASS. NAZARE'] at a distance of 70
# 1058.1747 Call 77: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 77
# Duration of the intervention 77 : 3.361111111111111
# 1061.5358 Call 77: Finished
# 1072.1388 Call 78 received from ['AGROVILA'] at a distance of 20
# 1072.1388 Call 78: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 78
# Duration of the intervention 78 : 1.1388888888888888
# 1073.2777 Call 78: Finished
# 1082.5307 Call 79 received from ['JARAQUI'] at a distance of 52
# 1082.5307 Call 79: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 79
# Duration of the intervention 79 : 2.561111111111111
# 1085.0919 Call 79: Finished
# 1108.9984 Call 80 received from ['JARAQUI'] at a distance of 52
# 1108.9984 Call 80: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 80
# Duration of the intervention 80 : 2.561111111111111
# 1111.5595 Call 80: Finished
# 1113.6043 Call 81 received from ['JARAQUI'] at a distance of 52
# 1113.6043 Call 81: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 81
# 1113.6317 Call 82 received from ['BONSUCESSO'] at a distance of 80
# Duration of the intervention 81 : 2.561111111111111
# 1116.1655 Call 81: Finished
# 1116.1655 Call 82: Waited  2.534
# Boat 1 with a speed of 45 respond to the call 82
# Duration of the intervention 82 : 3.8055555555555554
# 1119.9710 Call 82: Finished
# 1189.2571 Call 83 received from ['LIVRAMENTO'] at a distance of 15
# 1189.2571 Call 83: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 83
# Duration of the intervention 83 : 0.9166666666666666
# 1190.1738 Call 83: Finished
# 1191.1897 Call 84 received from ['N SRA CARMO'] at a distance of 100
# 1191.1897 Call 84: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 84
# Duration of the intervention 84 : 4.694444444444445
# 1195.8841 Call 84: Finished
# 1207.5421 Call 85 received from ['JARAQUI'] at a distance of 52
# 1207.5421 Call 85: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 85
# Duration of the intervention 85 : 2.561111111111111
# 1210.1032 Call 85: Finished
# 1212.5267 Call 86 received from ['N SRA CARMO'] at a distance of 100
# 1212.5267 Call 86: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 86
# Duration of the intervention 86 : 4.694444444444445
# 1217.2212 Call 86: Finished
# 1223.7308 Call 87 received from ['ARUAU'] at a distance of 100
# 1223.7308 Call 87: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 87
# Duration of the intervention 87 : 4.694444444444445
# 1228.4253 Call 87: Finished
# 1261.1885 Call 88 received from ['N. SRA. FATIMA'] at a distance of 15
# 1261.1885 Call 88: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 88
# Duration of the intervention 88 : 0.9166666666666666
# 1262.1052 Call 88: Finished
# 1276.7808 Call 89 received from ['N SRA CARMO'] at a distance of 100
# 1276.7808 Call 89: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 89
# Duration of the intervention 89 : 4.694444444444445
# 1281.4752 Call 89: Finished
# 1290.4993 Call 90 received from ['GUAJARA'] at a distance of 60
# 1290.4993 Call 90: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 90
# Duration of the intervention 90 : 2.9166666666666665
# 1293.4160 Call 90: Finished
# 1307.3714 Call 91 received from ['SANTA MARIA'] at a distance of 60
# 1307.3714 Call 91: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 91
# Duration of the intervention 91 : 2.9166666666666665
# 1310.2880 Call 91: Finished
# 1316.0495 Call 92 received from ['SANTA MARIA'] at a distance of 60
# 1316.0495 Call 92: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 92
# Duration of the intervention 92 : 2.9166666666666665
# 1318.9662 Call 92: Finished
# 1352.7354 Call 93 received from ['N SRA CARMO'] at a distance of 100
# 1352.7354 Call 93: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 93
# Duration of the intervention 93 : 4.694444444444445
# 1357.4298 Call 93: Finished
# 1362.0718 Call 94 received from ['SANTA MARIA'] at a distance of 60
# 1362.0718 Call 94: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 94
# Duration of the intervention 94 : 2.9166666666666665
# 1364.9884 Call 94: Finished
# 1386.6437 Call 95 received from ['AGROVILA'] at a distance of 20
# 1386.6437 Call 95: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 95
# Duration of the intervention 95 : 1.1388888888888888
# 1387.7826 Call 95: Finished
# 1389.0166 Call 96 received from ['BONSUCESSO'] at a distance of 80
# 1389.0166 Call 96: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 96
# Duration of the intervention 96 : 3.8055555555555554
# 1392.8222 Call 96: Finished
# 1395.7187 Call 97 received from ['AGROVILA'] at a distance of 20
# 1395.7187 Call 97: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 97
# Duration of the intervention 97 : 1.1388888888888888
# 1396.8576 Call 97: Finished
# 1405.3008 Call 98 received from ['ARUAU'] at a distance of 100
# 1405.3008 Call 98: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 98
# Duration of the intervention 98 : 4.694444444444445
# 1409.9952 Call 98: Finished
# 1417.5857 Call 99 received from ['COSTA DO TATU'] at a distance of 30
# 1417.5857 Call 99: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 99
# Duration of the intervention 99 : 1.5833333333333333
# 1419.1690 Call 99: Finished
# 1446.7817 Call 100 received from ['SANTA MARIA'] at a distance of 60
# 1446.7817 Call 100: Waited  0.000
# Boat 1 with a speed of 45 respond to the call 100
# Duration of the intervention 100 : 2.9166666666666665
# 1449.6984 Call 100: Finished
# list of intervention
# Intervention 1 : for call 1 with boat 1 take 1.5833333333333333
# Intervention 2 : for call 2 with boat 1 take 0.9166666666666666
# Intervention 3 : for call 3 with boat 1 take 2.9166666666666665
# Intervention 4 : for call 4 with boat 1 take 2.9166666666666665
# Intervention 5 : for call 5 with boat 1 take 2.561111111111111
# Intervention 6 : for call 6 with boat 1 take 4.694444444444445
# Intervention 7 : for call 7 with boat 1 take 3.5833333333333335
# Intervention 8 : for call 8 with boat 1 take 1.5833333333333333
# Intervention 9 : for call 9 with boat 1 take 4.25
# Intervention 10 : for call 10 with boat 1 take 4.694444444444445
# Intervention 11 : for call 11 with boat 1 take 3.8055555555555554
# Intervention 12 : for call 12 with boat 1 take 0.9166666666666666
# Intervention 13 : for call 13 with boat 1 take 2.561111111111111
# Intervention 14 : for call 14 with boat 1 take 1.5833333333333333
# Intervention 15 : for call 15 with boat 1 take 2.9166666666666665
# Intervention 16 : for call 16 with boat 1 take 4.25
# Intervention 17 : for call 17 with boat 1 take 4.694444444444445
# Intervention 18 : for call 18 with boat 1 take 2.4722222222222223
# Intervention 19 : for call 19 with boat 1 take 0.9166666666666666
# Intervention 20 : for call 20 with boat 1 take 1.1388888888888888
# Intervention 21 : for call 21 with boat 1 take 4.25
# Intervention 22 : for call 22 with boat 1 take 0.9166666666666666
# Intervention 23 : for call 23 with boat 1 take 4.694444444444445
# Intervention 24 : for call 24 with boat 1 take 3.5833333333333335
# Intervention 25 : for call 25 with boat 1 take 4.694444444444445
# Intervention 26 : for call 26 with boat 1 take 4.25
# Intervention 27 : for call 27 with boat 1 take 3.5833333333333335
# Intervention 28 : for call 28 with boat 1 take 2.561111111111111
# Intervention 29 : for call 29 with boat 1 take 3.361111111111111
# Intervention 30 : for call 30 with boat 1 take 4.25
# Intervention 31 : for call 31 with boat 1 take 4.694444444444445
# Intervention 32 : for call 32 with boat 1 take 2.9166666666666665
# Intervention 33 : for call 33 with boat 1 take 3.5833333333333335
# Intervention 34 : for call 34 with boat 1 take 3.5833333333333335
# Intervention 35 : for call 35 with boat 1 take 2.9166666666666665
# Intervention 36 : for call 36 with boat 1 take 2.4722222222222223
# Intervention 37 : for call 37 with boat 1 take 4.694444444444445
# Intervention 38 : for call 38 with boat 1 take 3.5833333333333335
# Intervention 39 : for call 39 with boat 1 take 2.4722222222222223
# Intervention 40 : for call 40 with boat 1 take 0.9166666666666666
# Intervention 41 : for call 41 with boat 1 take 1.5833333333333333
# Intervention 42 : for call 42 with boat 1 take 4.25
# Intervention 43 : for call 43 with boat 1 take 2.4722222222222223
# Intervention 44 : for call 44 with boat 1 take 2.9166666666666665
# Intervention 45 : for call 45 with boat 1 take 0.9166666666666666
# Intervention 46 : for call 46 with boat 1 take 2.4722222222222223
# Intervention 47 : for call 47 with boat 1 take 3.361111111111111
# Intervention 48 : for call 48 with boat 1 take 0.9166666666666666
# Intervention 49 : for call 49 with boat 1 take 2.4722222222222223
# Intervention 50 : for call 50 with boat 1 take 4.694444444444445
# Intervention 51 : for call 51 with boat 1 take 4.25
# Intervention 52 : for call 52 with boat 1 take 4.694444444444445
# Intervention 53 : for call 53 with boat 1 take 3.8055555555555554
# Intervention 54 : for call 54 with boat 1 take 4.694444444444445
# Intervention 55 : for call 55 with boat 1 take 0.9166666666666666
# Intervention 56 : for call 56 with boat 1 take 0.9166666666666666
# Intervention 57 : for call 57 with boat 1 take 0.9166666666666666
# Intervention 58 : for call 58 with boat 1 take 1.5833333333333333
# Intervention 59 : for call 59 with boat 1 take 3.5833333333333335
# Intervention 60 : for call 60 with boat 1 take 2.4722222222222223
# Intervention 61 : for call 61 with boat 1 take 1.5833333333333333
# Intervention 62 : for call 62 with boat 1 take 2.9166666666666665
# Intervention 63 : for call 63 with boat 1 take 0.9166666666666666
# Intervention 64 : for call 64 with boat 1 take 1.5833333333333333
# Intervention 65 : for call 65 with boat 1 take 4.25
# Intervention 66 : for call 66 with boat 1 take 1.5833333333333333
# Intervention 67 : for call 67 with boat 1 take 0.9166666666666666
# Intervention 68 : for call 68 with boat 1 take 2.9166666666666665
# Intervention 69 : for call 69 with boat 1 take 1.5833333333333333
# Intervention 70 : for call 70 with boat 1 take 1.1388888888888888
# Intervention 71 : for call 71 with boat 1 take 4.25
# Intervention 72 : for call 72 with boat 1 take 3.5833333333333335
# Intervention 73 : for call 73 with boat 1 take 0.9166666666666666
# Intervention 74 : for call 74 with boat 1 take 0.9166666666666666
# Intervention 75 : for call 75 with boat 1 take 0.9166666666666666
# Intervention 76 : for call 76 with boat 1 take 1.5833333333333333
# Intervention 77 : for call 77 with boat 1 take 3.361111111111111
# Intervention 78 : for call 78 with boat 1 take 1.1388888888888888
# Intervention 79 : for call 79 with boat 1 take 2.561111111111111
# Intervention 80 : for call 80 with boat 1 take 2.561111111111111
# Intervention 81 : for call 81 with boat 1 take 2.561111111111111
# Intervention 82 : for call 82 with boat 1 take 3.8055555555555554
# Intervention 83 : for call 83 with boat 1 take 0.9166666666666666
# Intervention 84 : for call 84 with boat 1 take 4.694444444444445
# Intervention 85 : for call 85 with boat 1 take 2.561111111111111
# Intervention 86 : for call 86 with boat 1 take 4.694444444444445
# Intervention 87 : for call 87 with boat 1 take 4.694444444444445
# Intervention 88 : for call 88 with boat 1 take 0.9166666666666666
# Intervention 89 : for call 89 with boat 1 take 4.694444444444445
# Intervention 90 : for call 90 with boat 1 take 2.9166666666666665
# Intervention 91 : for call 91 with boat 1 take 2.9166666666666665
# Intervention 92 : for call 92 with boat 1 take 2.9166666666666665
# Intervention 93 : for call 93 with boat 1 take 4.694444444444445
# Intervention 94 : for call 94 with boat 1 take 2.9166666666666665
# Intervention 95 : for call 95 with boat 1 take 1.1388888888888888
# Intervention 96 : for call 96 with boat 1 take 3.8055555555555554
# Intervention 97 : for call 97 with boat 1 take 1.1388888888888888
# Intervention 98 : for call 98 with boat 1 take 4.694444444444445
# Intervention 99 : for call 99 with boat 1 take 1.5833333333333333
# Intervention 100 : for call 100 with boat 1 take 2.9166666666666665

# %%
df = pandas.DataFrame.from_records([inter.to_dict() for inter in inter_list])
df
# Out:
#     Boat associated  Call traited  ID intervention  Time On Scene  \
# 0                 1             1                1           0.25
# 1                 1             2                2           0.25
# 2                 1             3                3           0.25
# 3                 1             4                4           0.25
# 4                 1             5                5           0.25
# 5                 1             6                6           0.25
# 6                 1             7                7           0.25
# 7                 1             8                8           0.25
# 8                 1             9                9           0.25
# 9                 1            10               10           0.25
# 10                1            11               11           0.25
# 11                1            12               12           0.25
# 12                1            13               13           0.25
# 13                1            14               14           0.25
# 14                1            15               15           0.25
# 15                1            16               16           0.25
# 16                1            17               17           0.25
# 17                1            18               18           0.25
# 18                1            19               19           0.25
# 19                1            20               20           0.25
# 20                1            21               21           0.25
# 21                1            22               22           0.25
# 22                1            23               23           0.25
# 23                1            24               24           0.25
# 24                1            25               25           0.25
# 25                1            26               26           0.25
# 26                1            27               27           0.25
# 27                1            28               28           0.25
# 28                1            29               29           0.25
# 29                1            30               30           0.25
# ..              ...           ...              ...            ...
# 70                1            71               71           0.25
# 71                1            72               72           0.25
# 72                1            73               73           0.25
# 73                1            74               74           0.25
# 74                1            75               75           0.25
# 75                1            76               76           0.25
# 76                1            77               77           0.25
# 77                1            78               78           0.25
# 78                1            79               79           0.25
# 79                1            80               80           0.25
# 80                1            81               81           0.25
# 81                1            82               82           0.25
# 82                1            83               83           0.25
# 83                1            84               84           0.25
# 84                1            85               85           0.25
# 85                1            86               86           0.25
# 86                1            87               87           0.25
# 87                1            88               88           0.25
# 88                1            89               89           0.25
# 89                1            90               90           0.25
# 90                1            91               91           0.25
# 91                1            92               92           0.25
# 92                1            93               93           0.25
# 93                1            94               94           0.25
# 94                1            95               95           0.25
# 95                1            96               96           0.25
# 96                1            97               97           0.25
# 97                1            98               98           0.25
# 98                1            99               99           0.25
# 99                1           100              100           0.25
#
#     response time  total time  travel time  waited time
# 0        0.666667    1.583333     0.666667     0.000000
# 1        0.333333    0.916667     0.333333     0.000000
# 2        1.333333    2.916667     1.333333     0.000000
# 3        1.333333    2.916667     1.333333     0.000000
# 4        1.155556    2.561111     1.155556     0.000000
# 5        2.222222    4.694444     2.222222     0.000000
# 6        5.042642    3.583333     1.666667     3.375976
# 7        3.056357    1.583333     0.666667     2.389691
# 8        2.000000    4.250000     2.000000     0.000000
# 9        2.938465    4.694444     2.222222     0.716243
# 10       1.777778    3.805556     1.777778     0.000000
# 11       1.797815    0.916667     0.333333     1.464482
# 12       1.155556    2.561111     1.155556     0.000000
# 13       0.666667    1.583333     0.666667     0.000000
# 14       1.333333    2.916667     1.333333     0.000000
# 15       2.000000    4.250000     2.000000     0.000000
# 16       2.222222    4.694444     2.222222     0.000000
# 17       1.111111    2.472222     1.111111     0.000000
# 18       0.333333    0.916667     0.333333     0.000000
# 19       0.444444    1.138889     0.444444     0.000000
# 20       2.000000    4.250000     2.000000     0.000000
# 21       0.333333    0.916667     0.333333     0.000000
# 22       2.222222    4.694444     2.222222     0.000000
# 23       1.666667    3.583333     1.666667     0.000000
# 24       3.852910    4.694444     2.222222     1.630688
# 25       4.303365    4.250000     2.000000     2.303365
# 26       3.027632    3.583333     1.666667     1.360966
# 27       1.155556    2.561111     1.155556     0.000000
# 28       3.250034    3.361111     1.555556     1.694479
# 29       2.000000    4.250000     2.000000     0.000000
# ..            ...         ...          ...          ...
# 70       2.000000    4.250000     2.000000     0.000000
# 71       1.666667    3.583333     1.666667     0.000000
# 72       1.710975    0.916667     0.333333     1.377642
# 73       0.333333    0.916667     0.333333     0.000000
# 74       0.333333    0.916667     0.333333     0.000000
# 75       0.666667    1.583333     0.666667     0.000000
# 76       1.555556    3.361111     1.555556     0.000000
# 77       0.444444    1.138889     0.444444     0.000000
# 78       1.155556    2.561111     1.155556     0.000000
# 79       1.155556    2.561111     1.155556     0.000000
# 80       1.155556    2.561111     1.155556     0.000000
# 81       4.311524    3.805556     1.777778     2.533746
# 82       0.333333    0.916667     0.333333     0.000000
# 83       2.222222    4.694444     2.222222     0.000000
# 84       1.155556    2.561111     1.155556     0.000000
# 85       2.222222    4.694444     2.222222     0.000000
# 86       2.222222    4.694444     2.222222     0.000000
# 87       0.333333    0.916667     0.333333     0.000000
# 88       2.222222    4.694444     2.222222     0.000000
# 89       1.333333    2.916667     1.333333     0.000000
# 90       1.333333    2.916667     1.333333     0.000000
# 91       1.333333    2.916667     1.333333     0.000000
# 92       2.222222    4.694444     2.222222     0.000000
# 93       1.333333    2.916667     1.333333     0.000000
# 94       0.444444    1.138889     0.444444     0.000000
# 95       1.777778    3.805556     1.777778     0.000000
# 96       0.444444    1.138889     0.444444     0.000000
# 97       2.222222    4.694444     2.222222     0.000000
# 98       0.666667    1.583333     0.666667     0.000000
# 99       1.333333    2.916667     1.333333     0.000000
#
# [100 rows x 8 columns]

# %%
with open('intervention.csv', 'w', newline='') as csvfile:
    fieldnames = ['ID_intervention', 'boat_associated', 'call_traited', 'travel_time', 'response_time', 'time_on_scene', 'waited_time', 'total_time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, dialect='excel', delimiter=';')

    writer.writeheader()
    for inter in inter_list: 
        writer.writerow({'ID_intervention': inter.ID, 'boat_associated': inter.boat.ID, 'call_traited': inter.call.ID, 
                        'travel_time': inter.travel_time, 'response_time': inter.response_time, 'time_on_scene': inter.TOS,
                        'waited_time': inter.waited_time, 'total_time': inter.road_time})

# %%
df.to_csv('test.csv', sep = ";")

# %%
#data statistic 

sum_wait = 0
sum_travel_time = 0
sum_response_time = 0 
sum_road_time = 0 
for inter in inter_list: 
    sum_wait = sum_wait + inter.waited_time 
    sum_travel_time = sum_travel_time + inter.travel_time
    sum_response_time = sum_response_time + inter.response_time 
    sum_road_time = sum_road_time + inter.road_time 
    
mean_wait = sum_wait / len(inter_list)
mean_travel_time = sum_travel_time / len(inter_list)
mean_response_time = sum_response_time / len(inter_list)
mean_road_time = sum_road_time / len(inter_list)

print("le temps d'attente moyen est {} ".format(mean_wait))
print("le temps de trajet moyen est {} ".format(mean_travel_time))
print("le temps de réponse moyen est {} ".format(mean_response_time))
print("le temps total d'intervention moyen est {} ".format(mean_road_time))
# Out:
# le temps d'attente moyen est 0.3078332180007577
# le temps de trajet moyen est 1.2708888888888887
# le temps de réponse moyen est 1.578722106889648
# le temps total d'intervention moyen est 2.791777777777778

# %%
gaps = []
gaps.append(call_list[0].initial_time)
for i in range (1,len(call_list)-1):
    gaps.append(call_list[i].initial_time-call_list[i-1].initial_time)
    
plt.hist(gaps)
plt.show()
